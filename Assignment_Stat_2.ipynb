# %% [markdown]
# #Theory Questions

# %% [markdown]
# Q1. What is a random variable in probability theory?
# - In probability theory, a random variable is a variable that takes on different values, each associated with a specific probability. It is a function that maps outcomes of a random experiment to real numbers.

# %% [markdown]
# Q2. What are the types of random variables?
# - 1. Discrete Random Variables
# - 2. Continuous Random Variables

# %% [markdown]
# Q3. What is the difference between discrete and continuous distributions?
#
# - Discrete Random Variables
#   - A discrete random variable takes on a countable number of distinct values.
#
#   - The possible values can be finite or countably infinite, but each value is distinct.
#
#   - Probability Distribution: Discrete random variables are typically described by a probability mass function (PMF), where each value has a specific probability.
# - Continuous Random Variables
#   - A continuous random variable can take on an infinite number of values within a given range or interval.
#
#   - These values are typically real numbers and can represent measurements.
#
#   - Probability Distribution: Continuous random variables are described by a probability density function (PDF). The probability that the variable takes an exact value is always zero, and probabilities are calculated over intervals (e.g., between 2.0 and 3.0).

# %% [markdown]
# Q4. What are probability distribution functions (PDF)?
# - A Probability Distribution Function (PDF) is a function that describes the likelihood or probability of a random variable taking specific values. It is used to model the behavior of random variables in both discrete and continuous distributions, though the exact definition and interpretation vary depending on the type of random variable.

# %% [markdown]
# Q5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# - A Probability Distribution Function (PDF) is a function that describes the likelihood or probability of a random variable taking specific values. It is used to model the behavior of random variables in both discrete and continuous distributions, though the exact definition and interpretation vary depending on the type of random variable.
# - For continuous random variables, the Probability Density Function (PDF) is used. The PDF describes the relative likelihood of a random variable taking a particular value, but it does not give the probability of the variable taking any exact value. Instead, it gives the probability that the variable will fall within a certain range or interval.

# %% [markdown]
# Q6. What is a discrete uniform distribution?
# - A discrete uniform distribution is a type of probability distribution where a discrete random variable has an equal probability of taking each of its possible values. In other words, each outcome in the sample space is equally likely to occur.
# - A discrete uniform distribution is a distribution where each possible outcome has an equal probability of occurring.
#
# The probability of each outcome is 1/n,where n is the number of possible outcomes.

# %% [markdown]
# Q7. What are the key properties of a Bernoulli distribution?
#
# Key Properties of a Bernoulli Distribution:
# 1. Two Possible Outcomes
# - A Bernoulli trial is an experiment or process that results in only two possible outcomes, often denoted as:
#
# - Success (typically denoted as 1), and
#
# - Failure (typically denoted as 0).
# 2. Probability of Success (p) and Failure (1 - p)
# - The probability of success is denoted by 𝑝, where 0≤𝑝≤1
# - The probability of failure is 1−p.

# %% [markdown]
# Q8. What is the binomial distribution, and how is it used in probability?
# - The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials of a Bernoulli experiment. Each trial has only two outcomes: success or failure.
#
# - Modeling Successes in Repeated Trials: The binomial distribution is useful when you have repeated, independent trials (such as coin tosses, product quality tests, survey responses) and you are interested in the number of successes.
#
# - Example:
#
# - You flip a fair coin 10 times (each flip being a trial).
#
# - You are interested in finding the probability of getting exactly 6 heads (successes) in these 10 flips.
#
# - Using the binomial distribution, you can calculate the probability of exactly 6 heads occurring.

# %% [markdown]
# Q9. What is the Poisson distribution and where is it applied?
# - The Poisson distribution is a discrete probability distribution that models the number of events occurring within a fixed interval of time or space, given that these events happen independently and at a constant average rate. It is often used to model rare or random events that occur in specific intervals, such as the number of calls received by a call center in an hour or the number of accidents at an intersection in a day.

# %% [markdown]
# Q10. What is a continuous uniform distribution?
# - The continuous uniform distribution is a type of probability distribution where all outcomes in a specified range are equally likely to occur. This distribution is defined over a continuous range of values, unlike the discrete uniform distribution, which deals with discrete outcomes.
#
# - In other words, if a random variable follows a continuous uniform distribution, the probability of the variable taking any value within a given interval is the same for every value in that interval.

# %% [markdown]
# Q11. What are the characteristics of a normal distribution?
# - The normal distribution is one of the most important distributions in statistics due to its widespread applicability in real-world data. It is symmetric, bell-shaped, and completely defined by its mean and standard deviation. Understanding its properties is crucial for statistical analysis and inference.

# %% [markdown]
# Q12. What is the standard normal distribution, and why is it important?
#
# - The standard normal distribution is a special case of the normal distribution, which is a bell-shaped curve that is symmetric about the mean. The standard normal distribution specifically has two key characteristics:
#
# - Mean (µ) = 0: The average value is zero.
#
# - Standard deviation (σ) = 1: The spread of the data is measured by a standard deviation of one.
# - Importance of the Standard Normal Distribution:
#   - Simplicity in Comparison: By standardizing different datasets (regardless of their original means and standard deviations), we can compare them on the same scale.
#
#  - Statistical Analysis: Many statistical tests, like hypothesis testing and confidence intervals, rely on the assumption of a normal distribution. Standardizing data to a Z-score allows us to use the properties of the standard normal distribution, making these tests easier to apply.
#
#  - Probability Calculation: The standard normal distribution allows us to easily calculate probabilities using Z-tables or computational tools. This helps in determining the likelihood of certain outcomes in a given dataset.

# %% [markdown]
# Q13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# - The Central Limit Theorem (CLT) is a fundamental concept in statistics that describes how the distribution of sample means (or sums) behaves when we repeatedly take random samples from a population.
# - Why the Central Limit Theorem is Critical in Statistics:
#   - Makes Inference Possible: The CLT enables statistical inference, which is the process of making predictions or generalizations about a population based on sample data. Thanks to the CLT, we can apply the properties of the normal distribution (such as using Z-scores) even when the population data isn't normally distributed, as long as the sample size is sufficiently large.
#
#   - Normality Assumption: Many statistical tests, like t-tests or confidence intervals, rely on the assumption that the sample mean follows a normal distribution. The CLT ensures that, for large enough sample sizes, this assumption holds true, regardless of the original population's distribution.

# %% [markdown]
# Q14. How does the Central Limit Theorem relate to the normal distribution?
# - Sample Means Become Normally Distributed: The CLT states that when you take random samples from any population (regardless of the population's original distribution), the distribution of the sample means will approximate a normal distribution as the sample size becomes larger. This is true even if the population from which the samples are drawn is not normally distributed.
#
# - For small sample sizes, the sample means may not be normally distributed.
#
# - As the sample size increases, the distribution of sample means becomes increasingly normal, approaching a normal distribution as the sample size gets large (typically
# n≥30 is considered large enough).
#
# - Population Distribution Doesn't Need to be Normal: One of the key points of the CLT is that the original population does not have to follow a normal distribution. Even if the population is skewed or has an unusual shape, the distribution of sample means will approach a normal distribution as long as the sample size is sufficiently large.

# %% [markdown]
# Q15. What is the application of Z statistics in hypothesis testing?
# - Z-statistics play a crucial role in hypothesis testing, particularly when the population is large or when the population standard deviation (
# 𝜎
# ) is known. Z-statistics are used to determine how far away a sample statistic (e.g., sample mean) is from the population parameter (e.g., population mean) in terms of standard errors. It allows us to assess whether a sample is significantly different from the population in question.

# %% [markdown]
# Q16. How do you calculate a Z-score, and what does it represent?
# - The formula to calculate the Z-score for a data point is:
#
# 𝑍
# =
# (X−μ)/
# ​𝜎
#
# Where:
#
# - 𝑋= the raw score or data point you want to standardize.
#
# - 𝜇 = the mean of the population or sample.
#
# - 𝜎= the standard deviation of the population or sample.
#
# Step-by-step process:
# - Find the mean (𝜇) of the dataset.
#
# Find the standard deviation (𝜎) of the dataset.
#
# Subtract the mean from the data point (𝑋−𝜇).
#
# Divide the result by the standard deviation (𝜎).

# %% [markdown]
# Q17. What are point estimates and interval estimates in statistics?
# - In statistics, point estimates and interval estimates are two different methods used to estimate population parameters based on sample data. Each approach provides a different level of precision and confidence about the true value of the parameter being estimated.

# %% [markdown]
# Q18. What is the significance of confidence intervals in statistical analysis?
# - A confidence interval (CI) is a range of values that is used to estimate a population parameter, such as the population mean, proportion, or difference between groups. The key feature of a confidence interval is that it includes an estimate of the parameter along with a measure of uncertainty about that estimate. This measure of uncertainty is expressed as a confidence level, such as 95% or 99%, which indicates how confident we are that the true population parameter lies within the interval.

# %% [markdown]
# Q19. What is the relationship between a Z-score and a confidence interval?
# - Z-score: A Z-score is a measure of how many standard deviations a particular value (such as a sample mean) is away from the population mean. It standardizes data to allow comparison across different datasets or distributions.
#
# - Formula for Z-score: 𝑍 = (𝑋 − 𝜇)/𝜎
#
# - Where: 𝑋 is the data point (or sample mean).
#
# - 𝜇 is the population mean.𝜎 is the population standard deviation.
#
# - Confidence Interval: A confidence interval is a range of values used to estimate a population parameter, such as the population mean or proportion, with a specific level of confidence (e.g., 95% confidence). It provides a range of plausible values for the population parameter, taking into account variability and sample size.
#
# - The formula for a confidence interval for a population mean (when the population standard deviation is known) is:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q20. How are Z-scores used to compare different distributions?
# - Z-scores are a standardized way of measuring how far a data point is from the mean of its distribution, expressed in terms of standard deviations. Z-scores help in comparing data points from different distributions, especially when those distributions have different means and standard deviations. By converting data points into Z-scores, you standardize them and make comparisons across different datasets or distributions meaningful.

# %% [markdown]
# Q21. What are the assumptions for applying the Central Limit Theorem?
# - The Central Limit Theorem (CLT) is a fundamental concept in statistics that describes how the distribution of sample means approaches a normal distribution as the sample size increases, regardless of the shape of the population distribution. However, to apply the CLT correctly, there are certain assumptions and conditions that need to be met.
# - Random sampling from the population.
#
# - Independence of the sample observations.
#
# - A sufficiently large sample size (typically
# 𝑛
# ≥
# 30
# is a good rule of thumb, with larger sizes for more skewed data).
#
# - The population should have finite variance.
#
# - For non-normal populations, avoid extreme skewness or outliers (a larger sample size may be needed for highly skewed populations).

# %% [markdown]
# Q22. What is the concept of expected value in a probability distribution?
# - The expected value (often denoted as
# 𝐸
# (
# 𝑋
# )
#  or
# 𝜇
# ) is a fundamental concept in probability and statistics. It represents the average or mean value of a random variable that you would expect to obtain over a long period of repeated trials or experiments. The expected value is essentially the "center" or "balance point" of a probability distribution.
#
# - In other words, the expected value is the weighted average of all possible outcomes of a random variable, where the weights are the probabilities of each outcome.

# %% [markdown]
# Q23. How does a probability distribution relate to the expected outcome of a random variable?
# - The expected value is essentially the weighted average of all possible values a random variable can take, where the weights are the probabilities associated with those values. In simple terms, the expected value tells you what the "average" outcome would be if you repeated an experiment many times.

# %% [markdown]
# #Practical Questions

# %%
#Q1. Write a Python program to generate a random variable and display its value.

import random

# Generate a random variable (integer) between 1 and 100
random_variable = random.randint(1, 100)

print("The random variable generated is:", random_variable)
# Out:
# The random variable generated is: 71

# %%
#Q2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

import numpy as np
import matplotlib.pyplot as plt

# Define the range for the discrete uniform distribution
low = 1    # Lower bound
high = 6   # Upper bound (exclusive)

# Generate a sample of 1000 random variables from a discrete uniform distribution
sample_size = 1000
random_variables = np.random.randint(low, high, sample_size)

# Calculate the probability mass function (PMF)
values, counts = np.unique(random_variables, return_counts=True)
pmf = counts / sample_size

# Plot the PMF
plt.bar(values, pmf, width=0.5, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Random Variable')
plt.ylabel('Probability')
plt.title('PMF of Discrete Uniform Distribution')

plt.show()

# %%
#Q3. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

import numpy as np
import matplotlib.pyplot as plt

# Parameters for the uniform distribution
low = 1   # The lowest integer value
high = 6  # The highest integer value

# Generate random samples from the discrete uniform distribution
samples = np.random.randint(low, high + 1, size=10000)

# Calculate the PMF (probability mass function)
values, counts = np.unique(samples, return_counts=True)

# Calculate probabilities (PMF)
probabilities = counts / len(samples)

# Plot the PMF
plt.bar(values, probabilities, width=0.7, align='center', color='blue', edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Probability')
plt.title('Probability Mass Function of Discrete Uniform Distribution')
plt.xticks(values)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#Q4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

import numpy as np
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n = 10  # Number of trials
p = 0.5  # Probability of success

# Simulate 10000 binomial random variables
data = np.random.binomial(n, p, 10000)

# Plotting the histogram
plt.hist(data, bins=np.arange(-0.5, n+1.5, 1), edgecolor='black', alpha=0.75)
plt.title('Binomial Distribution (n=10, p=0.5)')
plt.xlabel('Number of successes')
plt.ylabel('Frequency')
plt.xticks(range(0, n+1))
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
#Q5. Create a Poisson distribution and visualize it using Python.

import numpy as np
import matplotlib.pyplot as plt

# Parameters
lambda_ = 5  # Average rate (mean) of events
size = 1000  # Number of samples to generate

# Generating random data following a Poisson distribution
data = np.random.poisson(lam=lambda_, size=size)

# Plotting the histogram to visualize the Poisson distribution
plt.figure(figsize=(8, 6))
plt.hist(data, bins=range(0, max(data) + 1), edgecolor='black', alpha=0.7)

# Adding labels and title
plt.title('Poisson Distribution (lambda = 5)', fontsize=16)
plt.xlabel('Number of Events', fontsize=14)
plt.ylabel('Frequency', fontsize=14)


plt.show()

# %%
#Q6.  Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution

import numpy as np
import matplotlib.pyplot as plt

# Parameters for the discrete uniform distribution
a = 1  # Lower bound
b = 10  # Upper bound

# Values for the discrete random variable
x = np.arange(a, b+1)

# Probability mass function (PMF) for the discrete uniform distribution
pmf = np.ones_like(x) / len(x)

# Cumulative distribution function (CDF)
cdf = np.cumsum(pmf)

# Plotting the CDF
plt.step(x, cdf, where='post', label="CDF", color='blue', linestyle='-', linewidth=2)

# Adding labels and title
plt.title('Cumulative Distribution Function (CDF) of a Discrete Uniform Distribution')
plt.xlabel('x')
plt.ylabel('CDF(x)')
plt.xticks(x)
plt.grid(True, linestyle='--', alpha=0.7)


plt.show()

# %%
#Q7.  Generate a continuous uniform distribution using NumPy and visualize it.

import numpy as np
import matplotlib.pyplot as plt

# Parameters
low = 0  # Lower bound of the distribution
high = 10  # Upper bound of the distribution
size = 1000  # Number of samples to generate

# Generating random data following a continuous uniform distribution
data = np.random.uniform(low, high, size)

# Plotting the histogram to visualize the uniform distribution
plt.figure(figsize=(8, 6))
plt.hist(data, bins=30, edgecolor='black', alpha=0.7, density=True)

# Adding labels and title
plt.title('Continuous Uniform Distribution (low = 0, high = 10)', fontsize=16)
plt.xlabel('Value', fontsize=14)
plt.ylabel('Density', fontsize=14)

plt.show()

# %%
#Q8. Simulate data from a normal distribution and plot its histogram.

import numpy as np
import matplotlib.pyplot as plt

# Parameters for the normal distribution
mean = 0      # Mean of the distribution
std_dev = 1   # Standard deviation of the distribution
size = 10000  # Number of samples to generate

# Generate random data from the normal distribution
data = np.random.normal(loc=mean, scale=std_dev, size=size)

# Plot the histogram
plt.hist(data, bins=30, edgecolor='black', alpha=0.7)

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Normal Distribution')

plt.show()

# %%
#Q9. Write a Python function to calculate Z-scores from a dataset and plot them

import numpy as np
import matplotlib.pyplot as plt

# Function to calculate Z-scores
def calculate_z_scores(data):
    # Calculate the mean and standard deviation
    mean = np.mean(data)
    std_dev = np.std(data)

    # Calculate the Z-scores
    z_scores = (data - mean) / std_dev

    return z_scores

# Example dataset (can be any numeric data)
data = np.random.normal(loc=0, scale=1, size=1000)  # Generating random data

# Calculate Z-scores
z_scores = calculate_z_scores(data)

# Plot the Z-scores
plt.plot(z_scores, color='blue', alpha=0.7)
plt.axhline(y=0, color='black', linestyle='--', linewidth=1)  # Line at Z=0 for reference
plt.title('Z-scores of the Dataset')
plt.xlabel('Index')
plt.ylabel('Z-score')
plt.show()

# %%
#Q10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

import numpy as np
import matplotlib.pyplot as plt

# Parameters
population_size = 10000  # Size of the population
sample_size = 50  # Size of each sample
num_samples = 1000  # Number of samples to draw

# Generating a non-normal distribution (Exponential distribution)
population = np.random.exponential(scale=1.0, size=population_size)

# List to store the sample means
sample_means = []

# Drawing samples and computing their means
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size)
    sample_means.append(np.mean(sample))

# Convert the list of sample means to a numpy array for easier analysis
sample_means = np.array(sample_means)

# Plotting the histogram of sample means
plt.figure(figsize=(8, 6))
plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.7, density=True)

# Adding labels and title
plt.title('Central Limit Theorem Demonstration\nSample Means Distribution (Non-Normal Population)', fontsize=16)
plt.xlabel('Sample Mean', fontsize=14)
plt.ylabel('Density', fontsize=14)

plt.show()

# %%
#Q15. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

import numpy as np
import matplotlib.pyplot as plt

# Parameters for the normal distribution
mu = 0  # Mean of the distribution
sigma = 1  # Standard deviation of the distribution
n_samples = 10000  # Number of sample means to generate
sample_size = 30  # Size of each sample

# Generate random samples from a normal distribution
sample_means = []

# Simulate multiple samples and calculate their means
for _ in range(n_samples):
    sample = np.random.normal(mu, sigma, sample_size)
    sample_means.append(np.mean(sample))

# Convert the list of sample means to a numpy array
sample_means = np.array(sample_means)

# Plotting the histogram of sample means
plt.hist(sample_means, bins=30, edgecolor='black', alpha=0.75, density=True)

# Plotting the normal distribution (for comparison)
from scipy.stats import norm
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma / np.sqrt(sample_size))
plt.plot(x, p, 'k', linewidth=2)

# Adding labels and title
plt.title('Central Limit Theorem (CLT) Verification')
plt.xlabel('Sample Mean')
plt.ylabel('Density')

plt.show()

# %%
#Q16. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Function to calculate and plot the standard normal distribution
def plot_standard_normal_distribution():
    # Range of x values (from -4 to 4 for a reasonable range)
    x = np.linspace(-4, 4, 1000)

    # Calculate the standard normal distribution (mean=0, std=1)
    y = norm.pdf(x, 0, 1)

    # Plotting the standard normal distribution
    plt.plot(x, y, label='Standard Normal Distribution', color='blue', linewidth=2)

    # Adding labels and title
    plt.title('Standard Normal Distribution (mean=0, std=1)')
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.grid(True, linestyle='--', alpha=0.7)

    # Show the plot
    plt.legend()
    plt.show()

# Call the function to plot the distribution
plot_standard_normal_distribution()

# %%
#Q17. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters
n = 10  # Number of trials
p = 0.5  # Probability of success
size = 1000  # Number of random samples

# Generate random variables (number of successes in n trials)
random_variables = np.random.binomial(n, p, size)

# Calculate probabilities for each possible outcome (0 to n successes)
k_values = np.arange(0, n+1)
probabilities = binom.pmf(k_values, n, p)

# Plotting the histogram of the random variables
plt.figure(figsize=(8, 6))
plt.hist(random_variables, bins=np.arange(-0.5, n+1.5, 1), edgecolor='black', alpha=0.7, density=True)

# Plotting the PMF of the binomial distribution
plt.plot(k_values, probabilities, 'ro', label="Binomial PMF", markersize=8)

# Adding labels and title
plt.title('Binomial Distribution\nRandom Variables and Their Probabilities', fontsize=16)
plt.xlabel('Number of Successes', fontsize=14)
plt.ylabel('Probability', fontsize=14)

# Displaying the plot
plt.legend()
plt.show()

# %%
#Q18. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Function to calculate the Z-score for a given data point
def calculate_z_score(x, mean, std_dev):
    return (x - mean) / std_dev

# Example dataset (can be any numeric data)
data = np.random.normal(loc=0, scale=1, size=1000)  # Generating random data

# Given data point
data_point = 1.5

# Calculate mean and standard deviation of the dataset
mean = np.mean(data)
std_dev = np.std(data)

# Calculate the Z-score for the given data point
z_score = calculate_z_score(data_point, mean, std_dev)

# Calculate the cumulative probability (CDF) for the Z-score from a standard normal distribution
cdf_value = stats.norm.cdf(z_score)

# Print the Z-score and the corresponding cumulative probability (CDF)
print(f"Z-score for the data point {data_point}: {z_score}")
print(f"Cumulative probability for Z = {z_score}: {cdf_value}")

# Plot the standard normal distribution and mark the Z-score on the plot
x_values = np.linspace(-4, 4, 1000)  # X-axis values for plotting
y_values = stats.norm.pdf(x_values)  # Y-axis values for the standard normal distribution

plt.plot(x_values, y_values, label='Standard Normal Distribution', color='blue')
plt.axvline(x=z_score, color='red', linestyle='--', label=f'Z-score: {z_score:.2f}')
plt.title('Standard Normal Distribution and Z-score')
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Z-score for the data point 1.5: 1.494743749701016
# Cumulative probability for Z = 1.494743749701016: 0.9325093341660532

# %%
#Q19. Implement hypothesis testing using Z-statistics for a sample dataset.

import numpy as np
import scipy.stats as stats

# Function to perform hypothesis testing using Z-statistics
def hypothesis_testing_z(sample, population_mean, population_std, alpha=0.05):
    # Calculate the sample mean and sample size
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    # Calculate the Z-statistic
    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    # Calculate the p-value from the Z-statistic
    p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))  # Two-tailed test

    # Print the results
    print(f"Sample Mean: {sample_mean}")
    print(f"Z-statistic: {z_statistic}")
    print(f"P-value: {p_value}")

    # Determine whether to reject the null hypothesis
    if p_value < alpha:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")

# Example data
np.random.seed(0)
sample = np.random.normal(loc=100, scale=15, size=50)  # Sample from a normal distribution
population_mean = 105  # Population mean (hypothesized)
population_std = 15   # Population standard deviation

# Perform hypothesis testing using Z-statistics
hypothesis_testing_z(sample, population_mean, population_std, alpha=0.05)
# Out:
# Sample Mean: 102.10838908469648
# Z-statistic: -1.3631184578427709
# P-value: 0.1728451804900102
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.

# %%
#Q20. Create a confidence interval for a dataset using Python and interpret the result.

import numpy as np
import scipy.stats as stats

# Sample dataset
data = np.array([12, 15, 14, 10, 13, 16, 19, 21, 18, 17])

# Parameters
confidence_level = 0.95  # Confidence level (95%)
n = len(data)  # Sample size
mean = np.mean(data)  # Sample mean
std_dev = np.std(data, ddof=1)  # Sample standard deviation (ddof=1 for sample std deviation)

# Degrees of freedom
df = n - 1

# Calculate the t-value for the desired confidence level
t_value = stats.t.ppf((1 + confidence_level) / 2, df)

# Calculate the margin of error
margin_of_error = t_value * (std_dev / np.sqrt(n))

# Confidence interval
confidence_interval = (mean - margin_of_error, mean + margin_of_error)

# Output the result
print(f"Sample Mean: {mean:.2f}")
print(f"Sample Standard Deviation: {std_dev:.2f}")
print(f"Confidence Interval (95%): {confidence_interval[0]:.2f} to {confidence_interval[1]:.2f}")
# Out:
# Sample Mean: 15.50
# Sample Standard Deviation: 3.37
# Confidence Interval (95%): 13.09 to 17.91

# %%
#Q21. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

import numpy as np
import scipy.stats as stats

# Parameters for the normal distribution
mu = 50  # Mean of the distribution
sigma = 10  # Standard deviation of the distribution
n = 100  # Sample size
confidence_level = 0.95  # Confidence level (95%)

# Step 1: Generate random data from a normal distribution
data = np.random.normal(mu, sigma, n)

# Step 2: Calculate the sample mean and sample standard deviation
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # Sample standard deviation (use ddof=1 for unbiased estimator)
standard_error = sample_std / np.sqrt(n)

# Step 3: Calculate the z-score for the given confidence level
z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)  # For two-tailed confidence interval

# Step 4: Calculate the margin of error
margin_of_error = z_score * standard_error

# Step 5: Calculate the confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

# Display the results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Sample Standard Deviation: {sample_std:.2f}")
print(f"Standard Error: {standard_error:.2f}")
print(f"Confidence Interval ({confidence_level*100}%): ({confidence_interval[0]:.2f}, {confidence_interval[1]:.2f})")
# Out:
# Sample Mean: 51.18
# Sample Standard Deviation: 9.68
# Standard Error: 0.97
# Confidence Interval (95.0%): (49.28, 53.08)

# %%
#Q22. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Parameters for the normal distribution
mean = 0          # Mean of the distribution
std_dev = 1       # Standard deviation of the distribution

# Generate a range of values (e.g., between -5 and 5)
x_values = np.linspace(-5, 5, 1000)

# Calculate the PDF of the normal distribution for these values
pdf_values = stats.norm.pdf(x_values, loc=mean, scale=std_dev)

# Plot the PDF
plt.plot(x_values, pdf_values, label=f'Normal Distribution\nMean={mean}, Std={std_dev}', color='blue')
plt.fill_between(x_values, pdf_values, color='skyblue', alpha=0.4)

# Add labels and title
plt.title('Probability Density Function (PDF) of a Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
#Q23. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lambda_ = 5  # Average rate of occurrences (mean)
k_max = 15  # Maximum value to calculate CDF for

# Calculate the CDF for k values from 0 to k_max
k_values = np.arange(0, k_max+1)
cdf_values = poisson.cdf(k_values, lambda_)

# Plotting the CDF
plt.figure(figsize=(8, 6))
plt.step(k_values, cdf_values, where='post', label='Poisson CDF', color='blue', alpha=0.7)
plt.xlabel('Number of Events (k)', fontsize=14)
plt.ylabel('CDF', fontsize=14)
plt.title(f'Poisson CDF (λ = {lambda_})', fontsize=16)
plt.grid(True)
plt.legend()

# Display the plot
plt.show()

# Printing CDF values for interpretation
for k, cdf in zip(k_values, cdf_values):
    print(f'P(X ≤ {k}) = {cdf:.4f}')
# Out:
# P(X ≤ 0) = 0.0067
# P(X ≤ 1) = 0.0404
# P(X ≤ 2) = 0.1247
# P(X ≤ 3) = 0.2650
# P(X ≤ 4) = 0.4405
# P(X ≤ 5) = 0.6160
# P(X ≤ 6) = 0.7622
# P(X ≤ 7) = 0.8666
# P(X ≤ 8) = 0.9319
# P(X ≤ 9) = 0.9682
# P(X ≤ 10) = 0.9863
# P(X ≤ 11) = 0.9945
# P(X ≤ 12) = 0.9980
# P(X ≤ 13) = 0.9993
# P(X ≤ 14) = 0.9998
# P(X ≤ 15) = 0.9999

# %%
#Q24. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

import numpy as np

# Parameters for the continuous uniform distribution
a = 0  # Minimum value
b = 10  # Maximum value
n = 10000  # Number of random samples to simulate

# Step 1: Simulate random samples from a continuous uniform distribution
random_samples = np.random.uniform(a, b, n)

# Step 2: Calculate the sample mean (which is the estimate of the expected value)
sample_mean = np.mean(random_samples)

# Step 3: Calculate the theoretical expected value
theoretical_expected_value = (a + b) / 2

# Display results
print(f"Sample Mean (Estimated Expected Value): {sample_mean:.4f}")
print(f"Theoretical Expected Value: {theoretical_expected_value:.4f}")
# Out:
# Sample Mean (Estimated Expected Value): 4.9614
# Theoretical Expected Value: 5.0000

# %%
#Q25. Write a Python program to compare the standard deviations of two datasets and visualize the difference5

import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate two datasets (for example, normal distributions with different standard deviations)
np.random.seed(42)  # For reproducibility
data1 = np.random.normal(loc=50, scale=5, size=1000)  # Dataset 1: Mean=50, Std=5
data2 = np.random.normal(loc=50, scale=10, size=1000)  # Dataset 2: Mean=50, Std=10

# Step 2: Calculate the standard deviations of both datasets
std_data1 = np.std(data1)
std_data2 = np.std(data2)

# Step 3: Print the standard deviations
print(f"Standard Deviation of Dataset 1: {std_data1:.2f}")
print(f"Standard Deviation of Dataset 2: {std_data2:.2f}")

# Step 4: Visualize the datasets and their distributions

# Create a figure with subplots for histograms
plt.figure(figsize=(12, 6))

# Plot Dataset 1 histogram
plt.subplot(1, 2, 1)
plt.hist(data1, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.title(f"Dataset 1: Mean = {np.mean(data1):.2f}, Std = {std_data1:.2f}")
plt.xlabel('Value')
plt.ylabel('Frequency')

# Plot Dataset 2 histogram
plt.subplot(1, 2, 2)
plt.hist(data2, bins=30, color='salmon', edgecolor='black', alpha=0.7)
plt.title(f"Dataset 2: Mean = {np.mean(data2):.2f}, Std = {std_data2:.2f}")
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the plots
plt.tight_layout()
plt.show()
# Out:
# Standard Deviation of Dataset 1: 4.89
# Standard Deviation of Dataset 2: 9.97

# %%
#Q26. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

import numpy as np

# Parameters for the normal distribution
mean = 50  # Mean of the distribution
std_dev = 10  # Standard deviation of the distribution
size = 1000  # Size of the dataset

# Generate a dataset from a normal distribution
data = np.random.normal(mean, std_dev, size)

# Calculate the range
data_range = np.max(data) - np.min(data)

# Calculate the interquartile range (IQR)
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

# Output the results
print(f"Range: {data_range:.2f}")
print(f"Interquartile Range (IQR): {IQR:.2f}")
# Out:
# Range: 69.46
# Interquartile Range (IQR): 13.09

# %%
#Q27. Implement Z-score normalization on a dataset and visualize its transformation.

import numpy as np
import matplotlib.pyplot as plt

# Example dataset (can be any numeric data)
np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=1000)  # Normally distributed data with mean=50, std=15

# Calculate mean and standard deviation of the dataset
mean = np.mean(data)
std_dev = np.std(data)

# Z-score normalization
z_scores = (data - mean) / std_dev

# Plot the original and normalized data distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Plot original data distribution
ax1.hist(data, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
ax1.set_title('Original Data Distribution')
ax1.set_xlabel('Value')
ax1.set_ylabel('Frequency')

# Plot normalized data distribution
ax2.hist(z_scores, bins=30, color='lightgreen', edgecolor='black', alpha=0.7)
ax2.set_title('Normalized Data (Z-score) Distribution')
ax2.set_xlabel('Z-score')
ax2.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
#Q27. Implement Z-score normalization on a dataset and visualize its transformation.

import numpy as np
import matplotlib.pyplot as plt

# Example dataset (can be any numeric data)
np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=1000)  # Normally distributed data with mean=50, std=15

# Calculate the mean and standard deviation of the dataset
mean = np.mean(data)
std_dev = np.std(data)

# Z-score normalization: (X - mean) / std_dev
z_scores = (data - mean) / std_dev

# Plot the original and normalized data distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Plot original data distribution
ax1.hist(data, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
ax1.set_title('Original Data Distribution')
ax1.set_xlabel('Value')
ax1.set_ylabel('Frequency')

# Plot normalized data (Z-scores) distribution
ax2.hist(z_scores, bins=30, color='lightgreen', edgecolor='black', alpha=0.7)
ax2.set_title('Normalized Data (Z-score) Distribution')
ax2.set_xlabel('Z-score')
ax2.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
#Q28. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

import numpy as np
from scipy.stats import skew, kurtosis

# Function to calculate skewness and kurtosis
def calculate_skewness_kurtosis(data):
    # Calculate skewness
    skew_value = skew(data)

    # Calculate kurtosis (Fisher's definition, which subtracts 3 for normal distribution)
    kurtosis_value = kurtosis(data)

    return skew_value, kurtosis_value

# Parameters for the normal distribution
mean = 50  # Mean of the distribution
std_dev = 10  # Standard deviation of the distribution
size = 1000  # Size of the dataset

# Generate a dataset from a normal distribution
data = np.random.normal(mean, std_dev, size)

# Calculate skewness and kurtosis
skew_value, kurtosis_value = calculate_skewness_kurtosis(data)

# Output the results
print(f"Skewness: {skew_value:.4f}")
print(f"Kurtosis: {kurtosis_value:.4f}")
# Out:
# Skewness: -0.0493
# Kurtosis: 0.0521
